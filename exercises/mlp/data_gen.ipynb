# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 50
var = 0.5
# var = 0
x = np.linspace(0.1, 10, N)
y = x ** 0.5
# y = np.sin(x)
noise = np.random.normal(0, var, N)
y = y + noise

# %%
plt.scatter(x, y)
